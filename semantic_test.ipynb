# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
sentence_model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# 2025-09-06 15:18:56.351433: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757168336.593923   32411 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757168336.684151   32411 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1757168337.168390   32411 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757168337.168423   32411 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757168337.168428   32411 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757168337.168432   32411 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-06 15:18:57.185266: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Sample query and documents
query = ["Elon Musk, Mustapha"]
documents = [
    "Is the CEO",
    "Is in",
    "He leaves",
    "Is located in",
    "Kills",
    "No relation",
    
]

# Load Sentence-BERT model
model = SentenceTransformer('paraphrase-mpnet-base-v2')

# Generate embeddings
query_embedding = model.encode(query)
doc_embeddings = model.encode(documents)

# Compute cosine similarities
similarities = cosine_similarity(query_embedding, doc_embeddings)[0]

# Rank documents by similarity
ranked_indices = np.argsort(similarities)[::-1]  # Sort in descending order
print("Semantic Search Results:")
print(f"Query: {query[0]}")
print("\nRanked Documents:")
for i, idx in enumerate(ranked_indices):
    print(f"Rank {i+1}: {documents[idx]} (Cosine Similarity: {similarities[idx]:.4f})")
# Out:
# Semantic Search Results:
# Query: Elon Musk, Mustapha
#
# Ranked Documents:
# Rank 1: Is the CEO (Cosine Similarity: 0.2186)
# Rank 2: He leaves (Cosine Similarity: 0.1968)
# Rank 3: No relation (Cosine Similarity: 0.1343)
# Rank 4: Kills (Cosine Similarity: 0.1336)
# Rank 5: Is in (Cosine Similarity: 0.1252)
# Rank 6: Is located in (Cosine Similarity: 0.0825)
